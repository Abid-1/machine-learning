# %%
import pandas as pd

# %%
df=pd.read_csv("FuelConsumption.csv")

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.drop(columns=["MODELYEAR"], inplace=True)

# %%
df["MODEL"].value_counts()
# Out:
# MODEL
# F150 FFV 4X4                         8
# F150 FFV                             8
# BEETLE                               6
# FOCUS FFV                            6
# ACCORD                               6
# PASSAT                               5
# MUSTANG                              5
# SIERRA                               5
# SILVERADO                            5
# SILVERADO 4WD                        5
# SIERRA 4WD                           5
# FORTE 5                              4
# FUSION                               4
# FORTE KOUP                           4
# PATRIOT                              4
# IMPREZA AWD                          4
# TACOMA 4WD                           4
# IMPREZA WAGON AWD                    4
# FORTE                                4
# CRUZE                                4
# R8                                   4
# ATS                                  4
# CHARGER FFV                          4
# E150 VAN FFV                         4
# ...

# %%
df.head()
# Out:
#     MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA         ILX      COMPACT         2.0          4          AS5
# 1  ACURA         ILX      COMPACT         2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6          AS6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
# 2        Z                   6.0                  5.8                   5.9
# 3        Z                  12.7                  9.1                  11.1
# 4        Z                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# ...

# %%
df.head()
# Out:
#     MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 0  ACURA         ILX      COMPACT         2.0          4          AS5
# 1  ACURA         ILX      COMPACT         2.4          4           M6
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4          AV7
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6          AS6
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6          AS6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0        Z                   9.9                  6.7                   8.5
# 1        Z                  11.2                  7.7                   9.6
# 2        Z                   6.0                  5.8                   5.9
# 3        Z                  12.7                  9.1                  11.1
# 4        Z                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# ...

# %%
x=df.iloc[:,[0,1,2,3,4,5,6,11]].values
x
# Out:
# array([['ACURA', 'ILX', 'COMPACT', ..., 'AS5', 'Z', 196],
#        ['ACURA', 'ILX', 'COMPACT', ..., 'M6', 'Z', 221],
#        ['ACURA', 'ILX HYBRID', 'COMPACT', ..., 'AV7', 'Z', 136],
#        ...,
#        ['VOLVO', 'XC70 AWD', 'SUV - SMALL', ..., 'AS6', 'X', 271],
#        ['VOLVO', 'XC70 AWD', 'SUV - SMALL', ..., 'AS6', 'X', 260],
#        ['VOLVO', 'XC90 AWD', 'SUV - STANDARD', ..., 'AS6', 'X', 294]],
#       shape=(1067, 8), dtype=object)

# %%
y=df.iloc[:,[7,8,9,10]].values
y
# Out:
# array([[ 9.9,  6.7,  8.5, 33. ],
#        [11.2,  7.7,  9.6, 29. ],
#        [ 6. ,  5.8,  5.9, 48. ],
#        ...,
#        [13.4,  9.8, 11.8, 24. ],
#        [12.9,  9.3, 11.3, 25. ],
#        [14.9, 10.2, 12.8, 22. ]], shape=(1067, 4))

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()
le4=LabelEncoder()
le5=LabelEncoder()

x[:, 0] = le1.fit_transform(x[:, 0])
x[:, 1] = le2.fit_transform(x[:, 1])
x[:, 2] = le3.fit_transform(x[:, 2])
x[:, 5] = le4.fit_transform(x[:, 5])
x[:, 6] = le5.fit_transform(x[:, 6])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
acuracy=model.score(x_test, y_test)
print("Acuracy: ", acuracy)
# Out:
# Acuracy:  0.8284455262274097

# %%
new_data= [["ACURA","ILX","COMPACT",2.4,4,"M6","Z",221]] 
new_data[0] = le1.transform([new_data[0]])[0]
new_data[1] = le.transform([new_data[1]])[0]
new_data[2] = le.transform([new_data[2]])[0]
new_data[5] = le.transform([new_data[5]])[0]
new_data[6] = le.transform([new_data[6]])[0]  # Transform the city name
predicted_value = regressor.predict([new_data]) 
predicted_value

git config --global user.email "abidpala9055@gmail.com"
git config --global user.name "Abid-1"
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 new_data= [["ACURA","ILX","COMPACT",2.4,4,"M6","Z",221]]
# ----> 2 new_data[0] = le.transform([new_data[0]])[0]
#       3 new_data[1] = le.transform([new_data[1]])[0]
#       4 new_data[2] = le.transform([new_data[2]])[0]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\preprocessing\_label.py:127, in LabelEncoder.transform(self, y)
#     114 def transform(self, y):
#     115     """Transform labels to normalized encoding.
#     116
#     117     Parameters
#    (...)    125         Labels as normalized encodings.
#     126     """
# --> 127     check_is_fitted(self)
#     128     xp, _ = get_namespace(y)
#     129     y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#
# ...
